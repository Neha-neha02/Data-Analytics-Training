# %%
student_dct={
"name"



}

# %%
a=(1,2,3)
b=(4,5,6)
m=a*3
print(a)
# Out:
# (1, 2, 3)

# %%
a=1,2,22,2,2,2,2
print(a)
type(a)
len(a)

print("hii")
# Out:
# (1, 2, 22, 2, 2, 2, 2)
# 7

# %%
lst =[1,2,3,4,5]
for x in lst:
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
tpl=(1,2,3,4,54,5,5)
for x in tpl:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 54
# 5
# 5

# %%
def add(a,b):
    add(2,3)
    return()
print(add)
# Out:
# <function add at 0x0000027CF5328EA0>

# %%
a=10
name="Neha"
print(a)
print(name)
# Out:
# 10
# Neha

# %%
x=5
y=2.5
z="python"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
nama=input("Enter your name;")
print("Hello",name)
# Out:
# Hello Neha

# %%
x=True
y=False 
print(type(x))
# Out:
# <class 'bool'>

# %%
lst=[1,2,3]
print(type(lst))
# Out:
# <class 'list'>

# %%
def greet():
    print("Hello Neha")
greet()
# Out:
# Hello Neha

# %%
def add(a,b):
    print(a+b)
add(5,3)
# Out:
# 8

# %%
print("hii,i am neha")
# Out:
# hii,i am neha

# %%
#Q.1 python dictionary stores data in key-value pairs.
# and key cannot be change but value can change
my_dict = {1:"mango","name":"Neha",(2,3):"Tuple key "}
print(my_dict)
